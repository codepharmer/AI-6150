# %% [markdown]
# Aishwarya Singh <br>
# Nosson Weissman <br>
# DAV 6150 <br>
# June 7, 2022
#
# __DAV 6150 Practical Challenge 2 : Data Cleaning__

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Introduction

# %% [markdown]
# unga bunga blah blah

# %% [markdown]
# # Data Loading

# %% [markdown]
# We <<<>>>

# %%
raw_data = pd.read_csv('https://raw.githubusercontent.com/everyzig/DAV-6150/main/M3_Data.csv').drop('Unnamed: 0', axis = 1)

raw_data
# Out:
#        INDEX  TARGET  FixedAcidity  VolatileAcidity  CitricAcid  \
# 0          1       3           3.2            1.160        0.98
# 1          2       3           4.5            0.160        0.81
# 2          4       5           7.1            2.640        0.88
# 3          5       3           5.7            0.385        0.04
# 4          6       4           8.0            0.330        1.26
# ...      ...     ...           ...              ...         ...
# 12790  16120       0           5.0            0.790        2.01
# 12791  16123       5           8.9            0.470        0.29
# 12792  16127       4           6.0            0.170        1.10
# 12793  16128       3           7.7            0.320        0.12
# 12794  16129       4           5.2            0.040        0.81
#
#        ResidualSugar  Chlorides  FreeSulfurDioxide  TotalSulfurDioxide  \
# 0               54.2      0.567                NaN               268.0
# ...

# %%
raw_data.dtypes
# Out:
# INDEX                   int64
# TARGET                  int64
# FixedAcidity          float64
# VolatileAcidity       float64
# CitricAcid            float64
# ResidualSugar         float64
# Chlorides             float64
# FreeSulfurDioxide     float64
# TotalSulfurDioxide    float64
# Density               float64
# pH                    float64
# Sulphates             float64
# Alcohol               float64
# LabelAppeal             int64
# AcidIndex               int64
# STARS                 float64
# dtype: object

# %%
raw_data.isna().sum()
# Out:
# INDEX                    0
# TARGET                   0
# FixedAcidity             0
# VolatileAcidity          0
# CitricAcid               0
# ResidualSugar          616
# Chlorides              638
# FreeSulfurDioxide      647
# TotalSulfurDioxide     682
# Density                  0
# pH                     395
# Sulphates             1210
# Alcohol                653
# LabelAppeal              0
# AcidIndex                0
# STARS                 3359
# dtype: int64

# %%
raw_data.describe().INDEX
# Out:
# count    12795.000000
# mean      8069.980305
# std       4656.905107
# min          1.000000
# 25%       4037.500000
# 50%       8110.000000
# 75%      12106.500000
# max      16129.000000
# Name: INDEX, dtype: float64

# %% [markdown]
# # Exploratory Data Analysis & Quality Check

# %% [markdown]
# We conduct EDA etc. etc.

# %%
def eda_plot(df, col):
    '''Generate histogram and box plot for a given numeric attribute.'''
    plt.figure(figsize = (10,4))
    
    plt.subplot(1,2,1)
    plt.title('Histogram of ' + col)
    sns.histplot(x = df[col], kde = True)
    plt.subplot(1,2,2)
    plt.title('Box Plot of ' + col)
    sns.boxenplot(x = df[col])
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Numeric Variables

# %%
eda_plot(raw_data, 'Alcohol')

# %%
eda_plot(raw_data, 'Chlorides')

# %%
eda_plot(raw_data, 'CitricAcid')

# %%
eda_plot(raw_data, 'Density')

# %%
eda_plot(raw_data, 'FixedAcidity')

# %%
eda_plot(raw_data, 'FreeSulfurDioxide')

# %%
eda_plot(raw_data, 'ResidualSugar')

# %%
eda_plot(raw_data, 'Sulphates')

# %%
eda_plot(raw_data, 'TotalSulfurDioxide')

# %%
eda_plot(raw_data, 'VolatileAcidity')

# %%
eda_plot(raw_data, 'pH')

# %% [markdown]
# ## Categorical Variables

# %% [markdown]
# ### Target
# First we perform EDA on our response variable,

# %% [markdown]
# ### Acid Index

# %% [markdown]
# ### Label Appeal

# %% [markdown]
# ### STARS

# %% [markdown]
# # Data Preparation

# %% [markdown]
# # Conclusion

# %% [markdown]
# herpa derpa
